# %%
# !/usr/local/cuda/bin/nvcc --version
# !/opt/bin/nvidia-smi
# !nvidia-smi
import sys; print(sys.executable); print(sys.version) # Python version.
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Jun__8_16:49:14_PDT_2022
# Cuda compilation tools, release 11.7, V11.7.99
# Build cuda_11.7.r11.7/compiler.31442593_0
# /bin/bash: /opt/bin/nvidia-smi: No such file or directory
# Mon Mar 27 09:56:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A40          Off  | 00000000:81:00.0 Off |                    0 |
# ...

# %%
# from google.colab import drive
# drive.mount('/content/drive/') # To always mount w/o authentication, click Mount Drive in file explorer (side-bar).
# !cd "/content/drive/My Drive/code/DiffuSeq" && pip install -r requirements.txt
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# for browsing directory
# !cd "/content/drive/My Drive/code/DiffuSeq/datasets" && ls
# Out:
# CommonsenseConversation  GEC-9MB

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq" && \
# python scripts/run_train.py \
# --diff_steps 10 \
# --lr 0.0001 \
# --learning_steps 3 \
# --save_interval 10000 \
# --seed 102 \
# --noise_schedule sqrt \
# --hidden_dim 128 \
# --bsz 2 \
# --dataset qqp \
# --data_dir "datasets/CommonsenseConversation" \
# --vocab bert \
# --seq_len 128 \
# --schedule_sampler lossaware \
# --notes test-qqp
# Out:
# Traceback (most recent call last):
#   File "/content/drive/My Drive/code/DiffuSeq/scripts/run_train.py", line 45, in <module>
#     if int(os.environ['LOCAL_RANK']) == 0:
#   File "/usr/lib/python3.9/os.py", line 679, in __getitem__
#     raise KeyError(key) from None
# KeyError: 'LOCAL_RANK'

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq/scripts" && chmod a+wrx train_trivial.sh && ./train_trivial.sh

# !cd "/content/drive/My Drive/code/DiffuSeq" && \
python -m torch.distributed.launch --nproc_per_node=1 --master_port=12233 --use_env scripts/run_train.py \
--diff_steps 10 \
--lr 0.0001 \
--learning_steps 20 \
--save_interval 5 \
--seed 102 \
--noise_schedule sqrt \
--hidden_dim 128 \
--bsz 2 \
--dataset qqp \
--data_dir "datasets/CommonsenseConversation" \
--vocab bert \
--seq_len 128 \
--schedule_sampler lossaware \
--notes asdf

# --use_plm_init bert \
# Out:
# /bin/bash: line 0: cd: /content/drive/My Drive/code/DiffuSeq: No such file or directory

# %%
# !which python
# Out:
# /opt/conda/bin/python

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq" && \
python -m torch.distributed.launch --nproc_per_node=1 --master_port=12233 --use_env scripts/run_train.py \
--diff_steps 1000 \
--lr 0.0001 \
--learning_steps 20000 \
--save_interval 1000 \
--seed 102 \
--noise_schedule sqrt \
--hidden_dim 128 \
--bsz 32 \
--dataset gec \
--data_dir "datasets/GEC-9MB/err2corr" \
--vocab bert \
--seq_len 128 \
--schedule_sampler lossaware \
--notes gec_err2corr1

# --use_plm_init bert \
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/distributed/launch.py:180: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# ...
