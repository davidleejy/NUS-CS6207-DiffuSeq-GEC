# %%
# !/usr/local/cuda/bin/nvcc --version
# !/opt/bin/nvidia-smi
# !python --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# Mon Mar 27 05:45:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Python 3.9.16

# %%
from google.colab import drive
drive.mount('/content/drive/') # To always mount w/o authentication, click Mount Drive in file explorer (side-bar).
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq" && pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 KB 5.2 MB/s eta 0:00:00
# Collecting blobfile
#   Downloading blobfile-2.0.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (23.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (5.9.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (67.6.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (3.5.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (1.13.1+cu116)
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (4.65.0)
# Collecting transformers
#   Downloading transformers-4.27.3-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 46.4 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 38.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from bert_score->-r requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from bert_score->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from bert_score->-r requirements.txt (line 1)) (3.7.1)
# Collecting pycryptodomex~=3.8
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 77.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock~=3.0 in /usr/local/lib/python3.9/dist-packages (from blobfile->-r requirements.txt (line 2)) (3.10.1)
# Requirement already satisfied: lxml~=4.9 in /usr/local/lib/python3.9/dist-packages (from blobfile->-r requirements.txt (line 2)) (4.9.2)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /usr/local/lib/python3.9/dist-packages (from blobfile->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 3)) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 3)) (2022.10.31)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (1.0.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (8.1.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (1.10.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (2.4.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 12)) (4.5.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 107.5 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 30.6 MB/s eta 0:00:00
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 26.0 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 17)) (1.4.4)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 17)) (3.19.6)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.17.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 18)) (2023.3.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 18)) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 17.2 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.0 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 30.7 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r requirements.txt (line 18)) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 16.7 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r requirements.txt (line 18)) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 22.6 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.1->bert_score->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.1->bert_score->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->bert_score->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->bert_score->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 9)) (0.7.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy->-r requirements.txt (line 9)) (2.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert_score->-r requirements.txt (line 1)) (1.4.4)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->bert_score->-r requirements.txt (line 1)) (3.15.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=63c7709a7f112006b6b7e2baba25ca84ead547586738acbb5e646cdd6ff3d885
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built pathtools
# Installing collected packages: tokenizers, pathtools, xxhash, smmap, setproctitle, sentry-sdk, pycryptodomex, multidict, frozenlist, docker-pycreds, dill, async-timeout, yarl, torchmetrics, responses, multiprocess, huggingface-hub, gitdb, blobfile, aiosignal, transformers, GitPython, aiohttp, wandb, bert_score, datasets
# Successfully installed GitPython-3.1.31 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 bert_score-0.3.13 blobfile-2.0.1 datasets-2.10.1 dill-0.3.6 docker-pycreds-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 huggingface-hub-0.13.3 multidict-6.0.4 multiprocess-0.70.14 pathtools-0.1.2 pycryptodomex-3.17 responses-0.18.0 sentry-sdk-1.17.0 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.2 torchmetrics-0.11.4 transformers-4.27.3 wandb-0.14.0 xxhash-3.2.0 yarl-1.8.2

# %%
# for browsing directory
# !cd "/content/drive/My Drive/code/DiffuSeq/datasets" && ls
# Out:
# CommonsenseConversation  GEC-9MB

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq" && \
# python scripts/run_train.py \
# --diff_steps 10 \
# --lr 0.0001 \
# --learning_steps 3 \
# --save_interval 10000 \
# --seed 102 \
# --noise_schedule sqrt \
# --hidden_dim 128 \
# --bsz 2 \
# --dataset qqp \
# --data_dir "datasets/CommonsenseConversation" \
# --vocab bert \
# --seq_len 128 \
# --schedule_sampler lossaware \
# --notes test-qqp
# Out:
# Traceback (most recent call last):
#   File "/content/drive/My Drive/code/DiffuSeq/scripts/run_train.py", line 45, in <module>
#     if int(os.environ['LOCAL_RANK']) == 0:
#   File "/usr/lib/python3.9/os.py", line 679, in __getitem__
#     raise KeyError(key) from None
# KeyError: 'LOCAL_RANK'

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq/scripts" && chmod a+wrx train_trivial.sh && ./train_trivial.sh

# !cd "/content/drive/My Drive/code/DiffuSeq" && \
python -m torch.distributed.launch --nproc_per_node=1 --master_port=12233 --use_env scripts/run_train.py \
--diff_steps 10 \
--lr 0.0001 \
--learning_steps 20 \
--save_interval 5 \
--seed 102 \
--noise_schedule sqrt \
--hidden_dim 128 \
--bsz 2 \
--dataset qqp \
--data_dir "datasets/CommonsenseConversation" \
--vocab bert \
--seq_len 128 \
--schedule_sampler lossaware \
--notes asdf

# --use_plm_init bert \

# %%
# !cd "/content/drive/My Drive/code/DiffuSeq" && \
python -m torch.distributed.launch --nproc_per_node=1 --master_port=12233 --use_env scripts/run_train.py \
--diff_steps 1000 \
--lr 0.0001 \
--learning_steps 20000 \
--save_interval 1000 \
--seed 102 \
--noise_schedule sqrt \
--hidden_dim 128 \
--bsz 32 \
--dataset gec \
--data_dir "datasets/GEC-9MB/err2corr" \
--vocab bert \
--seq_len 128 \
--schedule_sampler lossaware \
--notes gec_err2corr1

# --use_plm_init bert \
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/distributed/launch.py:180: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
#  OPENAI_LOGDIR=diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25  TOKENIZERS_PARALLELISM=false python train.py   --checkpoint_path diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25 --dataset gec --data_dir datasets/GEC-9MB/err2corr --vocab bert --use_plm_init no --lr 0.0001 --batch_size 32 --microbatch 64 --diffusion_steps 1000 --noise_schedule sqrt --schedule_sampler lossaware --resume_checkpoint none --seq_len 128 --hidden_t_dim 128 --seed 102 --hidden_dim 128 --learning_steps 20000 --save_interval 1000 --config_name bert-base-uncased --notes gec_err2corr120230327-06:17:25
# 2023-03-27 06:17:30.954924: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-27 06:17:30.955079: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-27 06:17:30.955106: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Logging to diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25
# ### Creating data loader...
# initializing the random embeddings Embedding(30522, 128)
# ##############################
# Loading text data...
# ##############################
# Loading dataset gec from datasets/GEC-9MB/err2corr...
# ### Loading form the TRAIN set...
# ### Data samples...
#  ['My town is a medium size city with eighty thousand inhabitants .', 'It has a high density population because its small territory .'] ['My town is a medium - sized city with eighty thousand inhabitants .', 'It has a high - density population because of its small territory .']
# RAM used: 785.52 MB
# Dataset({
#     features: ['src', 'trg'],
#     num_rows: 96966
# })
# RAM used: 810.87 MB
# ### tokenized_datasets Dataset({
#     features: ['input_id_x', 'input_id_y'],
#     num_rows: 96966
# })
# ### tokenized_datasets...example [101, 2026, 2237, 2003, 1037, 5396, 2946, 2103, 2007, 12021, 4595, 4864, 1012, 102]
# RAM used: 858.02 MB
# RAM used: 928.80 MB
# Dataset({
#     features: ['input_id_x', 'input_id_y', 'input_ids', 'input_mask'],
#     num_rows: 96966
# }) padded dataset
# RAM used: 1105.41 MB
# RAM used: 1089.29 MB
# ##############################
# Loading text data...
# ##############################
# Loading dataset gec from datasets/GEC-9MB/err2corr...
# ### Loading form the VALID set...
# ### Data samples...
#  ['It \'s difficult answer at the question " what are you going to do in the future ? " if the only one who has to know it is in two minds .', "When I was younger I used to say that I wanted to be a teacher , a saleswoman and even a butcher .. I do n't know why ."] ['It \'s difficult to answer the question " what are you going to do in the future ? " if the only one who has to know it is in two minds .', "When I was younger , I used to say that I wanted to be a teacher , a saleswoman and even a butcher . I do n't know why ."]
# RAM used: 1000.73 MB
# Dataset({
#     features: ['src', 'trg'],
#     num_rows: 10959
# })
# RAM used: 1004.91 MB
# ### tokenized_datasets Dataset({
#     features: ['input_id_x', 'input_id_y'],
#     num_rows: 10959
# })
# ### tokenized_datasets...example [101, 2009, 1005, 1055, 3697, 3437, 2012, 1996, 3160, 1000, 2054, 2024, 2017, 2183, 2000, 2079, 1999, 1996, 2925, 1029, 1000, 2065, 1996, 2069, 2028, 2040, 2038, 2000, 2113, 2009, 2003, 1999, 2048, 9273, 1012, 102]
# RAM used: 1014.54 MB
# RAM used: 1028.32 MB
# Dataset({
#     features: ['input_id_x', 'input_id_y', 'input_ids', 'input_mask'],
#     num_rows: 10959
# }) padded dataset
# RAM used: 1048.05 MB
# RAM used: 1048.05 MB
# ############################## size of vocab 30522
# ### Creating model and diffusion...
# ### The parameter count is 91225274
# ### Saving the hyperparameters to diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25/training_args.json
# wandb: Currently logged in as: dl123. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.14.0
# wandb: Run data is saved locally in /content/drive/My Drive/code/DiffuSeq/wandb/run-20230327_061814-j83mlvx6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25
# wandb: ⭐️ View project at https://wandb.ai/dl123/DiffuSeq
# wandb: 🚀 View run at https://wandb.ai/dl123/DiffuSeq/runs/j83mlvx6
# ### Training...
# cuda:0
# ------------------------
# | grad_norm | 1.42     |
# | loss      | 0.958    |
# | loss_q0   | 0.97     |
# | loss_q1   | 0.959    |
# | loss_q2   | 0.956    |
# | loss_q3   | 0.948    |
# | mse       | 0.958    |
# | mse_q0    | 0.97     |
# | mse_q1    | 0.959    |
# | mse_q2    | 0.956    |
# | mse_q3    | 0.948    |
# | nll       | 12.6     |
# | nll_q0    | 12.7     |
# | nll_q1    | 12.7     |
# | nll_q2    | 12.4     |
# | nll_q3    | 12.6     |
# | samples   | 32       |
# | step      | 0        |
# ------------------------
# eval on validation set
# ---------------------------
# | eval_loss    | 0.7      |
# | eval_loss_q0 | 0.741    |
# | eval_loss_q1 | 0.686    |
# | eval_loss_q2 | 0.685    |
# | eval_loss_q3 | 0.709    |
# | eval_mse     | 0.7      |
# | eval_mse_q0  | 0.741    |
# | eval_mse_q1  | 0.686    |
# | eval_mse_q2  | 0.685    |
# | eval_mse_q3  | 0.709    |
# | eval_nll     | 8.06     |
# | eval_nll_q0  | 9.72     |
# | eval_nll_q1  | 7.48     |
# | eval_nll_q2  | 7.46     |
# | eval_nll_q3  | 8.41     |
# ---------------------------
# ------------------------
# | grad_norm | 0.328    |
# | loss      | 0.568    |
# | loss_q0   | 0.586    |
# | loss_q1   | 0.548    |
# | loss_q2   | 0.548    |
# | loss_q3   | 0.592    |
# | mse       | 0.568    |
# | mse_q0    | 0.586    |
# | mse_q1    | 0.548    |
# | mse_q2    | 0.548    |
# | mse_q3    | 0.592    |
# | nll       | 15.1     |
# | nll_q0    | 16       |
# | nll_q1    | 14       |
# | nll_q2    | 13.9     |
# | nll_q3    | 16.7     |
# | samples   | 672      |
# | step      | 20       |
# ------------------------
# ------------------------
# | grad_norm | 1.37     |
# | loss      | 0.589    |
# | loss_q0   | 0.579    |
# | loss_q1   | 0.56     |
# | loss_q2   | 0.6      |
# | loss_q3   | 0.617    |
# | mse       | 0.589    |
# | mse_q0    | 0.579    |
# | mse_q1    | 0.56     |
# | mse_q2    | 0.6      |
# | mse_q3    | 0.617    |
# | nll       | 16.4     |
# | nll_q0    | 16.1     |
# | nll_q1    | 14.4     |
# | nll_q2    | 17.4     |
# | nll_q3    | 17.8     |
# | samples   | 1.31e+03 |
# | step      | 40       |
# ------------------------
# ------------------------
# | grad_norm | 0.323    |
# | loss      | 0.527    |
# | loss_q0   | 0.541    |
# | loss_q1   | 0.548    |
# | loss_q2   | 0.511    |
# | loss_q3   | 0.509    |
# | mse       | 0.527    |
# | mse_q0    | 0.541    |
# | mse_q1    | 0.548    |
# | mse_q2    | 0.511    |
# | mse_q3    | 0.509    |
# | nll       | 14       |
# | nll_q0    | 14.7     |
# | nll_q1    | 14.9     |
# | nll_q2    | 13.2     |
# | nll_q3    | 13.1     |
# | samples   | 1.95e+03 |
# | step      | 60       |
# ------------------------
# ------------------------
# | grad_norm | 0.306    |
# | loss      | 0.385    |
# | loss_q0   | 0.365    |
# | loss_q1   | 0.355    |
# | loss_q2   | 0.377    |
# | loss_q3   | 0.435    |
# | mse       | 0.385    |
# | mse_q0    | 0.365    |
# | mse_q1    | 0.355    |
# | mse_q2    | 0.377    |
# | mse_q3    | 0.435    |
# | nll       | 6.01     |
# | nll_q0    | 4.62     |
# | nll_q1    | 4.47     |
# | nll_q2    | 6.54     |
# | nll_q3    | 8.06     |
# | samples   | 2.59e+03 |
# | step      | 80       |
# ------------------------
# ------------------------
# | grad_norm | 0.148    |
# | loss      | 0.36     |
# | loss_q0   | 0.338    |
# | loss_q1   | 0.329    |
# | loss_q2   | 0.398    |
# | loss_q3   | 0.379    |
# | mse       | 0.36     |
# | mse_q0    | 0.338    |
# | mse_q1    | 0.329    |
# | mse_q2    | 0.398    |
# | mse_q3    | 0.379    |
# | nll       | 3.83     |
# | nll_q0    | 2.57     |
# | nll_q1    | 3.07     |
# | nll_q2    | 4.61     |
# | nll_q3    | 5.2      |
# | samples   | 3.23e+03 |
# | step      | 100      |
# ------------------------
# ------------------------
# | grad_norm | 0.169    |
# | loss      | 0.351    |
# | loss_q0   | 0.35     |
# | loss_q1   | 0.338    |
# | loss_q2   | 0.336    |
# | loss_q3   | 0.378    |
# | mse       | 0.351    |
# | mse_q0    | 0.35     |
# | mse_q1    | 0.338    |
# | mse_q2    | 0.336    |
# | mse_q3    | 0.378    |
# | nll       | 3.35     |
# | nll_q0    | 2.18     |
# | nll_q1    | 2.22     |
# | nll_q2    | 2.47     |
# | nll_q3    | 6.21     |
# | samples   | 3.87e+03 |
# | step      | 120      |
# ------------------------
# ------------------------
# | grad_norm | 0.164    |
# | loss      | 0.36     |
# | loss_q0   | 0.352    |
# | loss_q1   | 0.336    |
# | loss_q2   | 0.369    |
# | loss_q3   | 0.386    |
# | mse       | 0.36     |
# | mse_q0    | 0.352    |
# | mse_q1    | 0.336    |
# | mse_q2    | 0.369    |
# | mse_q3    | 0.386    |
# | nll       | 3.08     |
# | nll_q0    | 2.35     |
# | nll_q1    | 2.2      |
# | nll_q2    | 2.69     |
# | nll_q3    | 5.27     |
# | samples   | 4.51e+03 |
# | step      | 140      |
# ------------------------
# ------------------------
# | grad_norm | 0.13     |
# | loss      | 0.348    |
# | loss_q0   | 0.326    |
# | loss_q1   | 0.352    |
# | loss_q2   | 0.331    |
# | loss_q3   | 0.382    |
# | mse       | 0.348    |
# | mse_q0    | 0.326    |
# | mse_q1    | 0.352    |
# | mse_q2    | 0.331    |
# | mse_q3    | 0.382    |
# | nll       | 3.28     |
# | nll_q0    | 2.29     |
# | nll_q1    | 2.53     |
# | nll_q2    | 2.45     |
# | nll_q3    | 5.9      |
# | samples   | 5.15e+03 |
# | step      | 160      |
# ------------------------
# ------------------------
# | grad_norm | 0.146    |
# | loss      | 0.336    |
# | loss_q0   | 0.311    |
# | loss_q1   | 0.338    |
# | loss_q2   | 0.351    |
# | loss_q3   | 0.347    |
# | mse       | 0.336    |
# | mse_q0    | 0.311    |
# | mse_q1    | 0.338    |
# | mse_q2    | 0.351    |
# | mse_q3    | 0.347    |
# | nll       | 3.14     |
# | nll_q0    | 2.32     |
# | nll_q1    | 2.57     |
# | nll_q2    | 2.88     |
# | nll_q3    | 4.77     |
# | samples   | 5.79e+03 |
# | step      | 180      |
# ------------------------
# ------------------------
# | grad_norm | 0.145    |
# | loss      | 0.309    |
# | loss_q0   | 0.3      |
# | loss_q1   | 0.285    |
# | loss_q2   | 0.331    |
# | loss_q3   | 0.32     |
# | mse       | 0.309    |
# | mse_q0    | 0.3      |
# | mse_q1    | 0.285    |
# | mse_q2    | 0.331    |
# | mse_q3    | 0.32     |
# | nll       | 2.97     |
# | nll_q0    | 2.12     |
# | nll_q1    | 2.06     |
# | nll_q2    | 2.7      |
# | nll_q3    | 5.09     |
# | samples   | 6.43e+03 |
# | step      | 200      |
# ------------------------
# ------------------------
# | grad_norm | 0.15     |
# | loss      | 0.279    |
# | loss_q0   | 0.274    |
# | loss_q1   | 0.283    |
# | loss_q2   | 0.269    |
# | loss_q3   | 0.289    |
# | mse       | 0.279    |
# | mse_q0    | 0.274    |
# | mse_q1    | 0.283    |
# | mse_q2    | 0.269    |
# | mse_q3    | 0.289    |
# | nll       | 2.54     |
# | nll_q0    | 1.79     |
# | nll_q1    | 2.07     |
# | nll_q2    | 2.23     |
# | nll_q3    | 3.83     |
# | samples   | 7.07e+03 |
# | step      | 220      |
# ------------------------
# ------------------------
# | grad_norm | 0.136    |
# | loss      | 0.263    |
# | loss_q0   | 0.263    |
# | loss_q1   | 0.243    |
# | loss_q2   | 0.26     |
# | loss_q3   | 0.288    |
# | mse       | 0.263    |
# | mse_q0    | 0.263    |
# | mse_q1    | 0.243    |
# | mse_q2    | 0.26     |
# | mse_q3    | 0.288    |
# | nll       | 2.52     |
# | nll_q0    | 1.65     |
# | nll_q1    | 1.66     |
# | nll_q2    | 2.17     |
# | nll_q3    | 4.62     |
# | samples   | 7.71e+03 |
# | step      | 240      |
# ------------------------
# ------------------------
# | grad_norm | 0.136    |
# | loss      | 0.249    |
# | loss_q0   | 0.235    |
# | loss_q1   | 0.232    |
# | loss_q2   | 0.232    |
# | loss_q3   | 0.301    |
# | mse       | 0.249    |
# | mse_q0    | 0.235    |
# | mse_q1    | 0.232    |
# | mse_q2    | 0.232    |
# | mse_q3    | 0.301    |
# | nll       | 2.34     |
# | nll_q0    | 1.3      |
# | nll_q1    | 1.54     |
# | nll_q2    | 1.92     |
# | nll_q3    | 4.87     |
# | samples   | 8.35e+03 |
# | step      | 260      |
# ------------------------
# ------------------------
# | grad_norm | 0.119    |
# | loss      | 0.225    |
# | loss_q0   | 0.201    |
# | loss_q1   | 0.215    |
# | loss_q2   | 0.229    |
# | loss_q3   | 0.258    |
# | mse       | 0.225    |
# | mse_q0    | 0.201    |
# | mse_q1    | 0.215    |
# | mse_q2    | 0.229    |
# | mse_q3    | 0.258    |
# | nll       | 1.99     |
# | nll_q0    | 0.789    |
# | nll_q1    | 1.28     |
# | nll_q2    | 1.86     |
# | nll_q3    | 4.31     |
# | samples   | 8.99e+03 |
# | step      | 280      |
# ------------------------
# ------------------------
# | grad_norm | 0.108    |
# | loss      | 0.214    |
# | loss_q0   | 0.178    |
# | loss_q1   | 0.205    |
# | loss_q2   | 0.216    |
# | loss_q3   | 0.251    |
# | mse       | 0.214    |
# | mse_q0    | 0.178    |
# | mse_q1    | 0.205    |
# | mse_q2    | 0.216    |
# | mse_q3    | 0.251    |
# | nll       | 1.76     |
# | nll_q0    | 0.49     |
# | nll_q1    | 0.996    |
# | nll_q2    | 1.61     |
# | nll_q3    | 3.75     |
# | samples   | 9.63e+03 |
# | step      | 300      |
# ------------------------
# ------------------------
# | grad_norm | 0.114    |
# | loss      | 0.201    |
# | loss_q0   | 0.158    |
# | loss_q1   | 0.202    |
# | loss_q2   | 0.201    |
# | loss_q3   | 0.24     |
# | mse       | 0.201    |
# | mse_q0    | 0.158    |
# | mse_q1    | 0.202    |
# | mse_q2    | 0.201    |
# | mse_q3    | 0.24     |
# | nll       | 1.57     |
# | nll_q0    | 0.296    |
# | nll_q1    | 0.856    |
# | nll_q2    | 1.4      |
# | nll_q3    | 3.59     |
# | samples   | 1.03e+04 |
# | step      | 320      |
# ------------------------
# ------------------------
# | grad_norm | 0.141    |
# | loss      | 0.198    |
# | loss_q0   | 0.167    |
# | loss_q1   | 0.186    |
# | loss_q2   | 0.175    |
# | loss_q3   | 0.251    |
# | mse       | 0.198    |
# | mse_q0    | 0.167    |
# | mse_q1    | 0.186    |
# | mse_q2    | 0.175    |
# | mse_q3    | 0.251    |
# | nll       | 1.69     |
# | nll_q0    | 0.254    |
# | nll_q1    | 0.711    |
# | nll_q2    | 1.13     |
# | nll_q3    | 4.03     |
# | samples   | 1.09e+04 |
# | step      | 340      |
# ------------------------
# ------------------------
# | grad_norm | 0.14     |
# | loss      | 0.182    |
# | loss_q0   | 0.151    |
# | loss_q1   | 0.156    |
# | loss_q2   | 0.187    |
# | loss_q3   | 0.229    |
# | mse       | 0.182    |
# | mse_q0    | 0.151    |
# | mse_q1    | 0.156    |
# | mse_q2    | 0.187    |
# | mse_q3    | 0.229    |
# | nll       | 1.47     |
# | nll_q0    | 0.207    |
# | nll_q1    | 0.463    |
# | nll_q2    | 1.29     |
# | nll_q3    | 3.68     |
# | samples   | 1.16e+04 |
# | step      | 360      |
# ------------------------
# ------------------------
# | grad_norm | 0.0937   |
# | loss      | 0.175    |
# | loss_q0   | 0.143    |
# | loss_q1   | 0.149    |
# | loss_q2   | 0.193    |
# | loss_q3   | 0.217    |
# | mse       | 0.175    |
# | mse_q0    | 0.143    |
# | mse_q1    | 0.149    |
# | mse_q2    | 0.193    |
# | mse_q3    | 0.217    |
# | nll       | 1.15     |
# | nll_q0    | 0.166    |
# | nll_q1    | 0.39     |
# | nll_q2    | 1.23     |
# | nll_q3    | 3.06     |
# | samples   | 1.22e+04 |
# | step      | 380      |
# ------------------------
# ------------------------
# | grad_norm | 0.106    |
# | loss      | 0.176    |
# | loss_q0   | 0.138    |
# | loss_q1   | 0.146    |
# | loss_q2   | 0.185    |
# | loss_q3   | 0.233    |
# | mse       | 0.176    |
# | mse_q0    | 0.138    |
# | mse_q1    | 0.146    |
# | mse_q2    | 0.185    |
# | mse_q3    | 0.233    |
# | nll       | 1.31     |
# | nll_q0    | 0.24     |
# | nll_q1    | 0.347    |
# | nll_q2    | 1.15     |
# | nll_q3    | 3.45     |
# | samples   | 1.28e+04 |
# | step      | 400      |
# ------------------------
# ------------------------
# | grad_norm | 0.114    |
# | loss      | 0.174    |
# | loss_q0   | 0.142    |
# | loss_q1   | 0.152    |
# | loss_q2   | 0.172    |
# | loss_q3   | 0.232    |
# | mse       | 0.174    |
# | mse_q0    | 0.142    |
# | mse_q1    | 0.152    |
# | mse_q2    | 0.172    |
# | mse_q3    | 0.232    |
# | nll       | 1.37     |
# | nll_q0    | 0.114    |
# | nll_q1    | 0.375    |
# | nll_q2    | 1.17     |
# | nll_q3    | 3.87     |
# | samples   | 1.35e+04 |
# | step      | 420      |
# ------------------------
# ------------------------
# | grad_norm | 0.104    |
# | loss      | 0.159    |
# | loss_q0   | 0.13     |
# | loss_q1   | 0.143    |
# | loss_q2   | 0.163    |
# | loss_q3   | 0.198    |
# | mse       | 0.159    |
# | mse_q0    | 0.13     |
# | mse_q1    | 0.143    |
# | mse_q2    | 0.163    |
# | mse_q3    | 0.198    |
# | nll       | 1.13     |
# | nll_q0    | 0.0865   |
# | nll_q1    | 0.328    |
# | nll_q2    | 0.951    |
# | nll_q3    | 3.05     |
# | samples   | 1.41e+04 |
# | step      | 440      |
# ------------------------
# ------------------------
# | grad_norm | 0.115    |
# | loss      | 0.159    |
# | loss_q0   | 0.128    |
# | loss_q1   | 0.133    |
# | loss_q2   | 0.167    |
# | loss_q3   | 0.206    |
# | mse       | 0.159    |
# | mse_q0    | 0.128    |
# | mse_q1    | 0.133    |
# | mse_q2    | 0.167    |
# | mse_q3    | 0.206    |
# | nll       | 1.12     |
# | nll_q0    | 0.0735   |
# | nll_q1    | 0.297    |
# | nll_q2    | 1.03     |
# | nll_q3    | 2.99     |
# | samples   | 1.48e+04 |
# | step      | 460      |
# ------------------------
# ------------------------
# | grad_norm | 0.112    |
# | loss      | 0.151    |
# | loss_q0   | 0.115    |
# | loss_q1   | 0.138    |
# | loss_q2   | 0.156    |
# | loss_q3   | 0.195    |
# | mse       | 0.151    |
# | mse_q0    | 0.115    |
# | mse_q1    | 0.138    |
# | mse_q2    | 0.156    |
# | mse_q3    | 0.195    |
# | nll       | 1.04     |
# | nll_q0    | 0.0358   |
# | nll_q1    | 0.237    |
# | nll_q2    | 0.912    |
# | nll_q3    | 3.01     |
# | samples   | 1.54e+04 |
# | step      | 480      |
# ------------------------
# ------------------------
# | grad_norm | 0.105    |
# | loss      | 0.145    |
# | loss_q0   | 0.113    |
# | loss_q1   | 0.125    |
# | loss_q2   | 0.15     |
# | loss_q3   | 0.204    |
# | mse       | 0.145    |
# | mse_q0    | 0.113    |
# | mse_q1    | 0.125    |
# | mse_q2    | 0.15     |
# | mse_q3    | 0.204    |
# | nll       | 1.03     |
# | nll_q0    | 0.0811   |
# | nll_q1    | 0.205    |
# | nll_q2    | 0.752    |
# | nll_q3    | 3.49     |
# | samples   | 1.6e+04  |
# | step      | 500      |
# ------------------------
# ------------------------
# | grad_norm | 0.144    |
# | loss      | 0.149    |
# | loss_q0   | 0.109    |
# | loss_q1   | 0.118    |
# | loss_q2   | 0.151    |
# | loss_q3   | 0.201    |
# | mse       | 0.149    |
# | mse_q0    | 0.109    |
# | mse_q1    | 0.118    |
# | mse_q2    | 0.151    |
# | mse_q3    | 0.201    |
# | nll       | 1.25     |
# | nll_q0    | 0.0335   |
# | nll_q1    | 0.175    |
# | nll_q2    | 0.921    |
# | nll_q3    | 3.27     |
# | samples   | 1.67e+04 |
# | step      | 520      |
# ------------------------
# ------------------------
# | grad_norm | 0.0897   |
# | loss      | 0.138    |
# | loss_q0   | 0.114    |
# | loss_q1   | 0.117    |
# | loss_q2   | 0.141    |
# | loss_q3   | 0.178    |
# | mse       | 0.138    |
# | mse_q0    | 0.114    |
# | mse_q1    | 0.117    |
# | mse_q2    | 0.141    |
# | mse_q3    | 0.178    |
# | nll       | 0.915    |
# | nll_q0    | 0.0562   |
# | nll_q1    | 0.166    |
# | nll_q2    | 0.813    |
# | nll_q3    | 2.56     |
# | samples   | 1.73e+04 |
# | step      | 540      |
# ------------------------
# ------------------------
# | grad_norm | 0.0891   |
# | loss      | 0.143    |
# | loss_q0   | 0.1      |
# | loss_q1   | 0.121    |
# | loss_q2   | 0.153    |
# | loss_q3   | 0.198    |
# | mse       | 0.143    |
# | mse_q0    | 0.1      |
# | mse_q1    | 0.121    |
# | mse_q2    | 0.153    |
# | mse_q3    | 0.198    |
# | nll       | 0.992    |
# | nll_q0    | 0.0305   |
# | nll_q1    | 0.157    |
# | nll_q2    | 0.863    |
# | nll_q3    | 2.88     |
# | samples   | 1.8e+04  |
# | step      | 560      |
# ------------------------
# ------------------------
# | grad_norm | 0.0887   |
# | loss      | 0.142    |
# | loss_q0   | 0.0981   |
# | loss_q1   | 0.124    |
# | loss_q2   | 0.136    |
# | loss_q3   | 0.21     |
# | mse       | 0.142    |
# | mse_q0    | 0.0981   |
# | mse_q1    | 0.124    |
# | mse_q2    | 0.136    |
# | mse_q3    | 0.21     |
# | nll       | 1.04     |
# | nll_q0    | 0.0317   |
# | nll_q1    | 0.182    |
# | nll_q2    | 0.663    |
# | nll_q3    | 3.34     |
# | samples   | 1.86e+04 |
# | step      | 580      |
# ------------------------
# ------------------------
# | grad_norm | 0.132    |
# | loss      | 0.139    |
# | loss_q0   | 0.0994   |
# | loss_q1   | 0.111    |
# | loss_q2   | 0.139    |
# | loss_q3   | 0.2      |
# | mse       | 0.139    |
# | mse_q0    | 0.0994   |
# | mse_q1    | 0.111    |
# | mse_q2    | 0.139    |
# | mse_q3    | 0.2      |
# | nll       | 1.19     |
# | nll_q0    | 0.0377   |
# | nll_q1    | 0.17     |
# | nll_q2    | 0.71     |
# | nll_q3    | 3.6      |
# | samples   | 1.92e+04 |
# | step      | 600      |
# ------------------------
# ------------------------
# | grad_norm | 0.104    |
# | loss      | 0.13     |
# | loss_q0   | 0.0939   |
# | loss_q1   | 0.114    |
# | loss_q2   | 0.124    |
# | loss_q3   | 0.189    |
# | mse       | 0.13     |
# | mse_q0    | 0.0939   |
# | mse_q1    | 0.114    |
# | mse_q2    | 0.124    |
# | mse_q3    | 0.189    |
# | nll       | 0.979    |
# | nll_q0    | 0.0212   |
# | nll_q1    | 0.157    |
# | nll_q2    | 0.692    |
# | nll_q3    | 3.14     |
# | samples   | 1.99e+04 |
# | step      | 620      |
# ------------------------
# ------------------------
# | grad_norm | 0.0912   |
# | loss      | 0.128    |
# | loss_q0   | 0.0851   |
# | loss_q1   | 0.107    |
# | loss_q2   | 0.134    |
# | loss_q3   | 0.178    |
# | mse       | 0.128    |
# | mse_q0    | 0.0851   |
# | mse_q1    | 0.107    |
# | mse_q2    | 0.134    |
# | mse_q3    | 0.178    |
# | nll       | 0.982    |
# | nll_q0    | 0.0204   |
# | nll_q1    | 0.137    |
# | nll_q2    | 0.792    |
# | nll_q3    | 2.77     |
# | samples   | 2.05e+04 |
# | step      | 640      |
# ------------------------
# ------------------------
# | grad_norm | 0.0813   |
# | loss      | 0.126    |
# | loss_q0   | 0.0912   |
# | loss_q1   | 0.116    |
# | loss_q2   | 0.126    |
# | loss_q3   | 0.176    |
# | mse       | 0.126    |
# | mse_q0    | 0.0912   |
# | mse_q1    | 0.116    |
# | mse_q2    | 0.126    |
# | mse_q3    | 0.176    |
# | nll       | 0.771    |
# | nll_q0    | 0.012    |
# | nll_q1    | 0.176    |
# | nll_q2    | 0.657    |
# | nll_q3    | 2.44     |
# | samples   | 2.12e+04 |
# | step      | 660      |
# ------------------------
# ------------------------
# | grad_norm | 0.0792   |
# | loss      | 0.125    |
# | loss_q0   | 0.0899   |
# | loss_q1   | 0.108    |
# | loss_q2   | 0.125    |
# | loss_q3   | 0.179    |
# | mse       | 0.125    |
# | mse_q0    | 0.0899   |
# | mse_q1    | 0.108    |
# | mse_q2    | 0.125    |
# | mse_q3    | 0.179    |
# | nll       | 0.802    |
# | nll_q0    | 0.0177   |
# | nll_q1    | 0.125    |
# | nll_q2    | 0.609    |
# | nll_q3    | 2.5      |
# | samples   | 2.18e+04 |
# | step      | 680      |
# ------------------------
# ------------------------
# | grad_norm | 0.0744   |
# | loss      | 0.12     |
# | loss_q0   | 0.0871   |
# | loss_q1   | 0.107    |
# | loss_q2   | 0.117    |
# | loss_q3   | 0.17     |
# | mse       | 0.12     |
# | mse_q0    | 0.0871   |
# | mse_q1    | 0.107    |
# | mse_q2    | 0.117    |
# | mse_q3    | 0.17     |
# | nll       | 0.761    |
# | nll_q0    | 0.0243   |
# | nll_q1    | 0.0957   |
# | nll_q2    | 0.528    |
# | nll_q3    | 2.36     |
# | samples   | 2.24e+04 |
# | step      | 700      |
# ------------------------
# ------------------------
# | grad_norm | 0.0964   |
# | loss      | 0.127    |
# | loss_q0   | 0.084    |
# | loss_q1   | 0.107    |
# | loss_q2   | 0.119    |
# | loss_q3   | 0.192    |
# | mse       | 0.127    |
# | mse_q0    | 0.084    |
# | mse_q1    | 0.107    |
# | mse_q2    | 0.119    |
# | mse_q3    | 0.192    |
# | nll       | 1.04     |
# | nll_q0    | 0.0105   |
# | nll_q1    | 0.117    |
# | nll_q2    | 0.624    |
# | nll_q3    | 3.2      |
# | samples   | 2.31e+04 |
# | step      | 720      |
# ------------------------
# ------------------------
# | grad_norm | 0.081    |
# | loss      | 0.12     |
# | loss_q0   | 0.0837   |
# | loss_q1   | 0.105    |
# | loss_q2   | 0.129    |
# | loss_q3   | 0.157    |
# | mse       | 0.12     |
# | mse_q0    | 0.0837   |
# | mse_q1    | 0.105    |
# | mse_q2    | 0.129    |
# | mse_q3    | 0.157    |
# | nll       | 0.771    |
# | nll_q0    | 0.00984  |
# | nll_q1    | 0.104    |
# | nll_q2    | 0.719    |
# | nll_q3    | 2.09     |
# | samples   | 2.37e+04 |
# | step      | 740      |
# ------------------------
# ------------------------
# | grad_norm | 0.0866   |
# | loss      | 0.12     |
# | loss_q0   | 0.0853   |
# | loss_q1   | 0.102    |
# | loss_q2   | 0.128    |
# | loss_q3   | 0.171    |
# | mse       | 0.12     |
# | mse_q0    | 0.0853   |
# | mse_q1    | 0.102    |
# | mse_q2    | 0.128    |
# | mse_q3    | 0.171    |
# | nll       | 0.82     |
# | nll_q0    | 0.0141   |
# | nll_q1    | 0.0897   |
# | nll_q2    | 0.793    |
# | nll_q3    | 2.61     |
# | samples   | 2.44e+04 |
# | step      | 760      |
# ------------------------
# ------------------------
# | grad_norm | 0.0845   |
# | loss      | 0.117    |
# | loss_q0   | 0.0799   |
# | loss_q1   | 0.0973   |
# | loss_q2   | 0.119    |
# | loss_q3   | 0.171    |
# | mse       | 0.117    |
# | mse_q0    | 0.0799   |
# | mse_q1    | 0.0973   |
# | mse_q2    | 0.119    |
# | mse_q3    | 0.171    |
# | nll       | 0.837    |
# | nll_q0    | 0.00999  |
# | nll_q1    | 0.103    |
# | nll_q2    | 0.648    |
# | nll_q3    | 2.51     |
# | samples   | 2.5e+04  |
# | step      | 780      |
# ------------------------
# ------------------------
# | grad_norm | 0.08     |
# | loss      | 0.118    |
# | loss_q0   | 0.0768   |
# | loss_q1   | 0.0993   |
# | loss_q2   | 0.128    |
# | loss_q3   | 0.167    |
# | mse       | 0.118    |
# | mse_q0    | 0.0768   |
# | mse_q1    | 0.0993   |
# | mse_q2    | 0.128    |
# | mse_q3    | 0.167    |
# | nll       | 0.809    |
# | nll_q0    | 0.0124   |
# | nll_q1    | 0.0821   |
# | nll_q2    | 0.724    |
# | nll_q3    | 2.38     |
# | samples   | 2.56e+04 |
# | step      | 800      |
# ------------------------
# ------------------------
# | grad_norm | 0.0796   |
# | loss      | 0.114    |
# | loss_q0   | 0.0717   |
# | loss_q1   | 0.0977   |
# | loss_q2   | 0.122    |
# | loss_q3   | 0.176    |
# | mse       | 0.114    |
# | mse_q0    | 0.0717   |
# | mse_q1    | 0.0977   |
# | mse_q2    | 0.122    |
# | mse_q3    | 0.176    |
# | nll       | 0.841    |
# | nll_q0    | 0.00546  |
# | nll_q1    | 0.115    |
# | nll_q2    | 0.723    |
# | nll_q3    | 2.77     |
# | samples   | 2.63e+04 |
# | step      | 820      |
# ------------------------
# ------------------------
# | grad_norm | 0.0825   |
# | loss      | 0.115    |
# | loss_q0   | 0.0783   |
# | loss_q1   | 0.0991   |
# | loss_q2   | 0.115    |
# | loss_q3   | 0.169    |
# | mse       | 0.115    |
# | mse_q0    | 0.0783   |
# | mse_q1    | 0.0991   |
# | mse_q2    | 0.115    |
# | mse_q3    | 0.169    |
# | nll       | 0.83     |
# | nll_q0    | 0.00736  |
# | nll_q1    | 0.106    |
# | nll_q2    | 0.575    |
# | nll_q3    | 2.68     |
# | samples   | 2.69e+04 |
# | step      | 840      |
# ------------------------
# ------------------------
# | grad_norm | 0.0735   |
# | loss      | 0.115    |
# | loss_q0   | 0.0883   |
# | loss_q1   | 0.114    |
# | loss_q2   | 0.124    |
# | loss_q3   | 0.125    |
# | mse       | 0.115    |
# | mse_q0    | 0.0883   |
# | mse_q1    | 0.114    |
# | mse_q2    | 0.124    |
# | mse_q3    | 0.125    |
# | nll       | 0.789    |
# | nll_q0    | 0.00236  |
# | nll_q1    | 0.104    |
# | nll_q2    | 0.647    |
# | nll_q3    | 1.9      |
# | samples   | 2.76e+04 |
# | step      | 860      |
# ------------------------
# ------------------------
# | grad_norm | 0.0821   |
# | loss      | 0.112    |
# | loss_q0   | 0.11     |
# | loss_q1   | 0.0984   |
# | loss_q2   | 0.111    |
# | loss_q3   | 0.122    |
# | mse       | 0.112    |
# | mse_q0    | 0.11     |
# | mse_q1    | 0.0984   |
# | mse_q2    | 0.111    |
# | mse_q3    | 0.122    |
# | nll       | 0.907    |
# | nll_q0    | 0.00974  |
# | nll_q1    | 0.0533   |
# | nll_q2    | 0.567    |
# | nll_q3    | 2.06     |
# | samples   | 2.82e+04 |
# | step      | 880      |
# ------------------------
# ------------------------
# | grad_norm | 0.0723   |
# | loss      | 0.106    |
# | loss_q0   | 0.108    |
# | loss_q1   | 0.0973   |
# | loss_q2   | 0.109    |
# | loss_q3   | 0.106    |
# | mse       | 0.106    |
# | mse_q0    | 0.108    |
# | mse_q1    | 0.0973   |
# | mse_q2    | 0.109    |
# | mse_q3    | 0.106    |
# | nll       | 0.742    |
# | nll_q0    | 0.0215   |
# | nll_q1    | 0.0814   |
# | nll_q2    | 0.578    |
# | nll_q3    | 1.57     |
# | samples   | 2.88e+04 |
# | step      | 900      |
# ------------------------
# ------------------------
# | grad_norm | 0.075    |
# | loss      | 0.111    |
# | loss_q0   | 0.0997   |
# | loss_q1   | 0.111    |
# | loss_q2   | 0.114    |
# | loss_q3   | 0.116    |
# | mse       | 0.111    |
# | mse_q0    | 0.0997   |
# | mse_q1    | 0.111    |
# | mse_q2    | 0.114    |
# | mse_q3    | 0.116    |
# | nll       | 0.846    |
# | nll_q0    | 0.00524  |
# | nll_q1    | 0.0875   |
# | nll_q2    | 0.614    |
# | nll_q3    | 1.87     |
# | samples   | 2.95e+04 |
# | step      | 920      |
# ------------------------
# ------------------------
# | grad_norm | 0.072    |
# | loss      | 0.107    |
# | loss_q0   | 0.101    |
# | loss_q1   | 0.106    |
# | loss_q2   | 0.111    |
# | loss_q3   | 0.108    |
# | mse       | 0.107    |
# | mse_q0    | 0.101    |
# | mse_q1    | 0.106    |
# | mse_q2    | 0.111    |
# | mse_q3    | 0.108    |
# | nll       | 0.747    |
# | nll_q0    | 0.0104   |
# | nll_q1    | 0.0728   |
# | nll_q2    | 0.586    |
# | nll_q3    | 1.61     |
# | samples   | 3.01e+04 |
# | step      | 940      |
# ------------------------
# ------------------------
# | grad_norm | 0.0744   |
# | loss      | 0.111    |
# | loss_q0   | 0.109    |
# | loss_q1   | 0.109    |
# | loss_q2   | 0.106    |
# | loss_q3   | 0.116    |
# | mse       | 0.111    |
# | mse_q0    | 0.109    |
# | mse_q1    | 0.109    |
# | mse_q2    | 0.106    |
# | mse_q3    | 0.116    |
# | nll       | 0.792    |
# | nll_q0    | 0.0108   |
# | nll_q1    | 0.108    |
# | nll_q2    | 0.497    |
# | nll_q3    | 1.87     |
# | samples   | 3.08e+04 |
# | step      | 960      |
# ------------------------
# ------------------------
# | grad_norm | 0.0717   |
# | loss      | 0.109    |
# | loss_q0   | 0.102    |
# | loss_q1   | 0.113    |
# | loss_q2   | 0.104    |
# | loss_q3   | 0.114    |
# | mse       | 0.109    |
# | mse_q0    | 0.102    |
# | mse_q1    | 0.113    |
# | mse_q2    | 0.104    |
# | mse_q3    | 0.114    |
# | nll       | 0.778    |
# | nll_q0    | 0.00611  |
# | nll_q1    | 0.112    |
# | nll_q2    | 0.526    |
# | nll_q3    | 1.81     |
# | samples   | 3.14e+04 |
# | step      | 980      |
# ------------------------
# ------------------------
# | grad_norm | 0.0769   |
# | loss      | 0.108    |
# | loss_q0   | 0.105    |
# | loss_q1   | 0.111    |
# | loss_q2   | 0.109    |
# | loss_q3   | 0.108    |
# | mse       | 0.108    |
# | mse_q0    | 0.105    |
# | mse_q1    | 0.111    |
# | mse_q2    | 0.109    |
# | mse_q3    | 0.108    |
# | nll       | 0.714    |
# | nll_q0    | 0.0263   |
# | nll_q1    | 0.0824   |
# | nll_q2    | 0.559    |
# | nll_q3    | 1.68     |
# | samples   | 3.2e+04  |
# | step      | 1e+03    |
# ------------------------
# eval on validation set
# ---------------------------
# | eval_loss    | 0.131    |
# | eval_loss_q0 | 0.0984   |
# | eval_loss_q1 | 0.0815   |
# | eval_loss_q2 | 0.12     |
# | eval_loss_q3 | 0.17     |
# | eval_mse     | 0.131    |
# | eval_mse_q0  | 0.0984   |
# | eval_mse_q1  | 0.0815   |
# | eval_mse_q2  | 0.12     |
# | eval_mse_q3  | 0.17     |
# | eval_nll     | 1.56     |
# | eval_nll_q0  | 9.88e-07 |
# | eval_nll_q1  | 0.195    |
# | eval_nll_q2  | 0.457    |
# | eval_nll_q3  | 3.39     |
# ---------------------------
# saving model 0.9999...
# writing to diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25/ema_0.9999_001000.pt
# writing to diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25/ema_0.9999_001000.pt
# ------------------------
# | grad_norm | 0.0708   |
# | loss      | 0.1      |
# | loss_q0   | 0.0993   |
# | loss_q1   | 0.101    |
# | loss_q2   | 0.101    |
# | loss_q3   | 0.0994   |
# | mse       | 0.1      |
# | mse_q0    | 0.0993   |
# | mse_q1    | 0.101    |
# | mse_q2    | 0.101    |
# | mse_q3    | 0.0994   |
# | nll       | 0.691    |
# | nll_q0    | 0.00606  |
# | nll_q1    | 0.102    |
# | nll_q2    | 0.515    |
# | nll_q3    | 1.49     |
# | samples   | 3.27e+04 |
# | step      | 1.02e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0742   |
# | loss      | 0.102    |
# | loss_q0   | 0.107    |
# | loss_q1   | 0.0972   |
# | loss_q2   | 0.0993   |
# | loss_q3   | 0.104    |
# | mse       | 0.102    |
# | mse_q0    | 0.107    |
# | mse_q1    | 0.0972   |
# | mse_q2    | 0.0993   |
# | mse_q3    | 0.104    |
# | nll       | 0.785    |
# | nll_q0    | 0.0102   |
# | nll_q1    | 0.0529   |
# | nll_q2    | 0.484    |
# | nll_q3    | 1.62     |
# | samples   | 3.33e+04 |
# | step      | 1.04e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0749   |
# | loss      | 0.105    |
# | loss_q0   | 0.0888   |
# | loss_q1   | 0.103    |
# | loss_q2   | 0.109    |
# | loss_q3   | 0.113    |
# | mse       | 0.105    |
# | mse_q0    | 0.0888   |
# | mse_q1    | 0.103    |
# | mse_q2    | 0.109    |
# | mse_q3    | 0.113    |
# | nll       | 0.79     |
# | nll_q0    | 0.00188  |
# | nll_q1    | 0.0738   |
# | nll_q2    | 0.634    |
# | nll_q3    | 1.9      |
# | samples   | 3.4e+04  |
# | step      | 1.06e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0731   |
# | loss      | 0.102    |
# | loss_q0   | 0.0988   |
# | loss_q1   | 0.1      |
# | loss_q2   | 0.0988   |
# | loss_q3   | 0.107    |
# | mse       | 0.102    |
# | mse_q0    | 0.0988   |
# | mse_q1    | 0.1      |
# | mse_q2    | 0.0988   |
# | mse_q3    | 0.107    |
# | nll       | 0.747    |
# | nll_q0    | 0.0115   |
# | nll_q1    | 0.0801   |
# | nll_q2    | 0.418    |
# | nll_q3    | 1.78     |
# | samples   | 3.46e+04 |
# | step      | 1.08e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0716   |
# | loss      | 0.104    |
# | loss_q0   | 0.0974   |
# | loss_q1   | 0.106    |
# | loss_q2   | 0.0981   |
# | loss_q3   | 0.11     |
# | mse       | 0.104    |
# | mse_q0    | 0.0974   |
# | mse_q1    | 0.106    |
# | mse_q2    | 0.0981   |
# | mse_q3    | 0.11     |
# | nll       | 0.731    |
# | nll_q0    | 0.00748  |
# | nll_q1    | 0.0758   |
# | nll_q2    | 0.417    |
# | nll_q3    | 1.71     |
# | samples   | 3.52e+04 |
# | step      | 1.1e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0707   |
# | loss      | 0.102    |
# | loss_q0   | 0.0977   |
# | loss_q1   | 0.0992   |
# | loss_q2   | 0.101    |
# | loss_q3   | 0.106    |
# | mse       | 0.102    |
# | mse_q0    | 0.0977   |
# | mse_q1    | 0.0992   |
# | mse_q2    | 0.101    |
# | mse_q3    | 0.106    |
# | nll       | 0.737    |
# | nll_q0    | 0.00714  |
# | nll_q1    | 0.0681   |
# | nll_q2    | 0.445    |
# | nll_q3    | 1.74     |
# | samples   | 3.59e+04 |
# | step      | 1.12e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0723   |
# | loss      | 0.102    |
# | loss_q0   | 0.0974   |
# | loss_q1   | 0.101    |
# | loss_q2   | 0.102    |
# | loss_q3   | 0.106    |
# | mse       | 0.102    |
# | mse_q0    | 0.0974   |
# | mse_q1    | 0.101    |
# | mse_q2    | 0.102    |
# | mse_q3    | 0.106    |
# | nll       | 0.755    |
# | nll_q0    | 0.0155   |
# | nll_q1    | 0.0709   |
# | nll_q2    | 0.462    |
# | nll_q3    | 1.78     |
# | samples   | 3.65e+04 |
# | step      | 1.14e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0697   |
# | loss      | 0.0987   |
# | loss_q0   | 0.0912   |
# | loss_q1   | 0.0993   |
# | loss_q2   | 0.0933   |
# | loss_q3   | 0.106    |
# | mse       | 0.0987   |
# | mse_q0    | 0.0912   |
# | mse_q1    | 0.0993   |
# | mse_q2    | 0.0933   |
# | mse_q3    | 0.106    |
# | nll       | 0.773    |
# | nll_q0    | 0.0124   |
# | nll_q1    | 0.0727   |
# | nll_q2    | 0.43     |
# | nll_q3    | 1.75     |
# | samples   | 3.72e+04 |
# | step      | 1.16e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0778   |
# | loss      | 0.098    |
# | loss_q0   | 0.0891   |
# | loss_q1   | 0.0922   |
# | loss_q2   | 0.101    |
# | loss_q3   | 0.105    |
# | mse       | 0.098    |
# | mse_q0    | 0.0891   |
# | mse_q1    | 0.0922   |
# | mse_q2    | 0.101    |
# | mse_q3    | 0.105    |
# | nll       | 0.749    |
# | nll_q0    | 0.0066   |
# | nll_q1    | 0.0566   |
# | nll_q2    | 0.468    |
# | nll_q3    | 1.81     |
# | samples   | 3.78e+04 |
# | step      | 1.18e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0721   |
# | loss      | 0.0974   |
# | loss_q0   | 0.0977   |
# | loss_q1   | 0.0978   |
# | loss_q2   | 0.0933   |
# | loss_q3   | 0.1      |
# | mse       | 0.0974   |
# | mse_q0    | 0.0977   |
# | mse_q1    | 0.0978   |
# | mse_q2    | 0.0933   |
# | mse_q3    | 0.1      |
# | nll       | 0.701    |
# | nll_q0    | 0.000883 |
# | nll_q1    | 0.062    |
# | nll_q2    | 0.399    |
# | nll_q3    | 1.66     |
# | samples   | 3.84e+04 |
# | step      | 1.2e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0736   |
# | loss      | 0.0948   |
# | loss_q0   | 0.0994   |
# | loss_q1   | 0.0944   |
# | loss_q2   | 0.0876   |
# | loss_q3   | 0.0981   |
# | mse       | 0.0948   |
# | mse_q0    | 0.0994   |
# | mse_q1    | 0.0944   |
# | mse_q2    | 0.0876   |
# | mse_q3    | 0.0981   |
# | nll       | 0.693    |
# | nll_q0    | 0.00998  |
# | nll_q1    | 0.0666   |
# | nll_q2    | 0.424    |
# | nll_q3    | 1.57     |
# | samples   | 3.91e+04 |
# | step      | 1.22e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0709   |
# | loss      | 0.096    |
# | loss_q0   | 0.0836   |
# | loss_q1   | 0.0936   |
# | loss_q2   | 0.0987   |
# | loss_q3   | 0.101    |
# | mse       | 0.096    |
# | mse_q0    | 0.0836   |
# | mse_q1    | 0.0936   |
# | mse_q2    | 0.0987   |
# | mse_q3    | 0.1      |
# | nll       | 0.768    |
# | nll_q0    | 0.00379  |
# | nll_q1    | 0.0394   |
# | nll_q2    | 0.462    |
# | nll_q3    | 1.65     |
# | samples   | 3.97e+04 |
# | step      | 1.24e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.068    |
# | loss      | 0.0969   |
# | loss_q0   | 0.094    |
# | loss_q1   | 0.0947   |
# | loss_q2   | 0.0947   |
# | loss_q3   | 0.101    |
# | mse       | 0.0969   |
# | mse_q0    | 0.094    |
# | mse_q1    | 0.0947   |
# | mse_q2    | 0.0947   |
# | mse_q3    | 0.101    |
# | nll       | 0.709    |
# | nll_q0    | 0.00286  |
# | nll_q1    | 0.076    |
# | nll_q2    | 0.445    |
# | nll_q3    | 1.66     |
# | samples   | 4.04e+04 |
# | step      | 1.26e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0716   |
# | loss      | 0.0974   |
# | loss_q0   | 0.0923   |
# | loss_q1   | 0.093    |
# | loss_q2   | 0.095    |
# | loss_q3   | 0.104    |
# | mse       | 0.0974   |
# | mse_q0    | 0.0923   |
# | mse_q1    | 0.093    |
# | mse_q2    | 0.095    |
# | mse_q3    | 0.104    |
# | nll       | 0.776    |
# | nll_q0    | 0.00448  |
# | nll_q1    | 0.0794   |
# | nll_q2    | 0.466    |
# | nll_q3    | 1.81     |
# | samples   | 4.1e+04  |
# | step      | 1.28e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0694   |
# | loss      | 0.0943   |
# | loss_q0   | 0.0896   |
# | loss_q1   | 0.0892   |
# | loss_q2   | 0.0971   |
# | loss_q3   | 0.0977   |
# | mse       | 0.0943   |
# | mse_q0    | 0.0896   |
# | mse_q1    | 0.0892   |
# | mse_q2    | 0.0971   |
# | mse_q3    | 0.0977   |
# | nll       | 0.715    |
# | nll_q0    | 0.00133  |
# | nll_q1    | 0.0654   |
# | nll_q2    | 0.417    |
# | nll_q3    | 1.57     |
# | samples   | 4.16e+04 |
# | step      | 1.3e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0721   |
# | loss      | 0.0969   |
# | loss_q0   | 0.0982   |
# | loss_q1   | 0.0936   |
# | loss_q2   | 0.0977   |
# | loss_q3   | 0.0972   |
# | mse       | 0.0969   |
# | mse_q0    | 0.0982   |
# | mse_q1    | 0.0936   |
# | mse_q2    | 0.0977   |
# | mse_q3    | 0.0972   |
# | nll       | 0.831    |
# | nll_q0    | 8.17e-05 |
# | nll_q1    | 0.0861   |
# | nll_q2    | 0.522    |
# | nll_q3    | 1.72     |
# | samples   | 4.23e+04 |
# | step      | 1.32e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0711   |
# | loss      | 0.0953   |
# | loss_q0   | 0.0907   |
# | loss_q1   | 0.0935   |
# | loss_q2   | 0.0997   |
# | loss_q3   | 0.0955   |
# | mse       | 0.0953   |
# | mse_q0    | 0.0907   |
# | mse_q1    | 0.0935   |
# | mse_q2    | 0.0997   |
# | mse_q3    | 0.0955   |
# | nll       | 0.748    |
# | nll_q0    | 0.00113  |
# | nll_q1    | 0.0756   |
# | nll_q2    | 0.481    |
# | nll_q3    | 1.62     |
# | samples   | 4.29e+04 |
# | step      | 1.34e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0635   |
# | loss      | 0.0922   |
# | loss_q0   | 0.0862   |
# | loss_q1   | 0.0909   |
# | loss_q2   | 0.0994   |
# | loss_q3   | 0.0902   |
# | mse       | 0.0922   |
# | mse_q0    | 0.0862   |
# | mse_q1    | 0.0909   |
# | mse_q2    | 0.0994   |
# | mse_q3    | 0.0902   |
# | nll       | 0.618    |
# | nll_q0    | 0.00214  |
# | nll_q1    | 0.0701   |
# | nll_q2    | 0.506    |
# | nll_q3    | 1.42     |
# | samples   | 4.36e+04 |
# | step      | 1.36e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0658   |
# | loss      | 0.0944   |
# | loss_q0   | 0.0843   |
# | loss_q1   | 0.0934   |
# | loss_q2   | 0.095    |
# | loss_q3   | 0.0991   |
# | mse       | 0.0944   |
# | mse_q0    | 0.0843   |
# | mse_q1    | 0.0934   |
# | mse_q2    | 0.095    |
# | mse_q3    | 0.0991   |
# | nll       | 0.775    |
# | nll_q0    | 0.00031  |
# | nll_q1    | 0.0856   |
# | nll_q2    | 0.441    |
# | nll_q3    | 1.78     |
# | samples   | 4.42e+04 |
# | step      | 1.38e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0692   |
# | loss      | 0.0945   |
# | loss_q0   | 0.0895   |
# | loss_q1   | 0.0858   |
# | loss_q2   | 0.103    |
# | loss_q3   | 0.097    |
# | mse       | 0.0945   |
# | mse_q0    | 0.0895   |
# | mse_q1    | 0.0858   |
# | mse_q2    | 0.103    |
# | mse_q3    | 0.097    |
# | nll       | 0.699    |
# | nll_q0    | 0.00199  |
# | nll_q1    | 0.0564   |
# | nll_q2    | 0.541    |
# | nll_q3    | 1.53     |
# | samples   | 4.48e+04 |
# | step      | 1.4e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0809   |
# | loss      | 0.0999   |
# | loss_q0   | 0.0936   |
# | loss_q1   | 0.0954   |
# | loss_q2   | 0.101    |
# | loss_q3   | 0.104    |
# | mse       | 0.0999   |
# | mse_q0    | 0.0936   |
# | mse_q1    | 0.0954   |
# | mse_q2    | 0.101    |
# | mse_q3    | 0.104    |
# | nll       | 0.836    |
# | nll_q0    | 0.00325  |
# | nll_q1    | 0.0551   |
# | nll_q2    | 0.548    |
# | nll_q3    | 1.82     |
# | samples   | 4.55e+04 |
# | step      | 1.42e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0688   |
# | loss      | 0.0925   |
# | loss_q0   | 0.089    |
# | loss_q1   | 0.0943   |
# | loss_q2   | 0.0949   |
# | loss_q3   | 0.0912   |
# | mse       | 0.0925   |
# | mse_q0    | 0.089    |
# | mse_q1    | 0.0943   |
# | mse_q2    | 0.0949   |
# | mse_q3    | 0.0912   |
# | nll       | 0.703    |
# | nll_q0    | 0.00218  |
# | nll_q1    | 0.0758   |
# | nll_q2    | 0.48     |
# | nll_q3    | 1.53     |
# | samples   | 4.61e+04 |
# | step      | 1.44e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.068    |
# | loss      | 0.0903   |
# | loss_q0   | 0.089    |
# | loss_q1   | 0.088    |
# | loss_q2   | 0.0891   |
# | loss_q3   | 0.0927   |
# | mse       | 0.0903   |
# | mse_q0    | 0.089    |
# | mse_q1    | 0.088    |
# | mse_q2    | 0.0891   |
# | mse_q3    | 0.0927   |
# | nll       | 0.758    |
# | nll_q0    | 0.00605  |
# | nll_q1    | 0.0367   |
# | nll_q2    | 0.404    |
# | nll_q3    | 1.62     |
# | samples   | 4.68e+04 |
# | step      | 1.46e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0658   |
# | loss      | 0.0898   |
# | loss_q0   | 0.0856   |
# | loss_q1   | 0.0943   |
# | loss_q2   | 0.0909   |
# | loss_q3   | 0.0888   |
# | mse       | 0.0898   |
# | mse_q0    | 0.0856   |
# | mse_q1    | 0.0943   |
# | mse_q2    | 0.0909   |
# | mse_q3    | 0.0888   |
# | nll       | 0.702    |
# | nll_q0    | 0.0107   |
# | nll_q1    | 0.0724   |
# | nll_q2    | 0.466    |
# | nll_q3    | 1.46     |
# | samples   | 4.74e+04 |
# | step      | 1.48e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0707   |
# | loss      | 0.0967   |
# | loss_q0   | 0.0886   |
# | loss_q1   | 0.0939   |
# | loss_q2   | 0.0978   |
# | loss_q3   | 0.101    |
# | mse       | 0.0967   |
# | mse_q0    | 0.0886   |
# | mse_q1    | 0.0939   |
# | mse_q2    | 0.0978   |
# | mse_q3    | 0.101    |
# | nll       | 0.83     |
# | nll_q0    | 0.000233 |
# | nll_q1    | 0.0694   |
# | nll_q2    | 0.507    |
# | nll_q3    | 1.82     |
# | samples   | 4.8e+04  |
# | step      | 1.5e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0743   |
# | loss      | 0.0908   |
# | loss_q0   | 0.0917   |
# | loss_q1   | 0.0914   |
# | loss_q2   | 0.0917   |
# | loss_q3   | 0.0896   |
# | mse       | 0.0908   |
# | mse_q0    | 0.0917   |
# | mse_q1    | 0.0914   |
# | mse_q2    | 0.0917   |
# | mse_q3    | 0.0896   |
# | nll       | 0.7      |
# | nll_q0    | 0.00198  |
# | nll_q1    | 0.0371   |
# | nll_q2    | 0.428    |
# | nll_q3    | 1.51     |
# | samples   | 4.87e+04 |
# | step      | 1.52e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.069    |
# | loss      | 0.0926   |
# | loss_q0   | 0.0884   |
# | loss_q1   | 0.0881   |
# | loss_q2   | 0.091    |
# | loss_q3   | 0.0974   |
# | mse       | 0.0926   |
# | mse_q0    | 0.0884   |
# | mse_q1    | 0.0881   |
# | mse_q2    | 0.091    |
# | mse_q3    | 0.0974   |
# | nll       | 0.803    |
# | nll_q0    | 0.000626 |
# | nll_q1    | 0.0661   |
# | nll_q2    | 0.453    |
# | nll_q3    | 1.66     |
# | samples   | 4.93e+04 |
# | step      | 1.54e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0658   |
# | loss      | 0.0881   |
# | loss_q0   | 0.088    |
# | loss_q1   | 0.0838   |
# | loss_q2   | 0.0885   |
# | loss_q3   | 0.0907   |
# | mse       | 0.0881   |
# | mse_q0    | 0.088    |
# | mse_q1    | 0.0838   |
# | mse_q2    | 0.0885   |
# | mse_q3    | 0.0907   |
# | nll       | 0.676    |
# | nll_q0    | 0.00699  |
# | nll_q1    | 0.063    |
# | nll_q2    | 0.364    |
# | nll_q3    | 1.63     |
# | samples   | 5e+04    |
# | step      | 1.56e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0668   |
# | loss      | 0.0932   |
# | loss_q0   | 0.0912   |
# | loss_q1   | 0.0878   |
# | loss_q2   | 0.0927   |
# | loss_q3   | 0.0972   |
# | mse       | 0.0932   |
# | mse_q0    | 0.0912   |
# | mse_q1    | 0.0878   |
# | mse_q2    | 0.0927   |
# | mse_q3    | 0.0972   |
# | nll       | 0.773    |
# | nll_q0    | 0.00201  |
# | nll_q1    | 0.0552   |
# | nll_q2    | 0.457    |
# | nll_q3    | 1.69     |
# | samples   | 5.06e+04 |
# | step      | 1.58e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0636   |
# | loss      | 0.0889   |
# | loss_q0   | 0.0829   |
# | loss_q1   | 0.0895   |
# | loss_q2   | 0.093    |
# | loss_q3   | 0.0885   |
# | mse       | 0.0889   |
# | mse_q0    | 0.0829   |
# | mse_q1    | 0.0895   |
# | mse_q2    | 0.093    |
# | mse_q3    | 0.0885   |
# | nll       | 0.671    |
# | nll_q0    | 0.00743  |
# | nll_q1    | 0.047    |
# | nll_q2    | 0.523    |
# | nll_q3    | 1.44     |
# | samples   | 5.12e+04 |
# | step      | 1.6e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.067    |
# | loss      | 0.0919   |
# | loss_q0   | 0.0874   |
# | loss_q1   | 0.094    |
# | loss_q2   | 0.0945   |
# | loss_q3   | 0.0908   |
# | mse       | 0.0919   |
# | mse_q0    | 0.0874   |
# | mse_q1    | 0.094    |
# | mse_q2    | 0.0945   |
# | mse_q3    | 0.0908   |
# | nll       | 0.755    |
# | nll_q0    | 0.0153   |
# | nll_q1    | 0.0555   |
# | nll_q2    | 0.481    |
# | nll_q3    | 1.56     |
# | samples   | 5.19e+04 |
# | step      | 1.62e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0656   |
# | loss      | 0.0918   |
# | loss_q0   | 0.0846   |
# | loss_q1   | 0.0895   |
# | loss_q2   | 0.0922   |
# | loss_q3   | 0.0956   |
# | mse       | 0.0918   |
# | mse_q0    | 0.0846   |
# | mse_q1    | 0.0895   |
# | mse_q2    | 0.0922   |
# | mse_q3    | 0.0956   |
# ...
# | step      | 2.04e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0656   |
# | loss      | 0.0818   |
# | loss_q0   | 0.0892   |
# | loss_q1   | 0.0847   |
# | loss_q2   | 0.0812   |
# | loss_q3   | 0.0787   |
# | mse       | 0.0818   |
# | mse_q0    | 0.0892   |
# | mse_q1    | 0.0847   |
# | mse_q2    | 0.0812   |
# | mse_q3    | 0.0787   |
# | nll       | 0.71     |
# | nll_q0    | 0.0038   |
# | nll_q1    | 0.0512   |
# | nll_q2    | 0.359    |
# | nll_q3    | 1.41     |
# | samples   | 6.6e+04  |
# | step      | 2.06e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0646   |
# | loss      | 0.0822   |
# | loss_q0   | 0.0777   |
# | loss_q1   | 0.0819   |
# | loss_q2   | 0.0802   |
# | loss_q3   | 0.085    |
# | mse       | 0.0822   |
# | mse_q0    | 0.0777   |
# | mse_q1    | 0.0819   |
# | mse_q2    | 0.0802   |
# | mse_q3    | 0.085    |
# | nll       | 0.743    |
# | nll_q0    | 0.000461 |
# | nll_q1    | 0.0274   |
# | nll_q2    | 0.355    |
# | nll_q3    | 1.53     |
# | samples   | 6.66e+04 |
# | step      | 2.08e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0659   |
# | loss      | 0.0814   |
# | loss_q0   | 0.0787   |
# | loss_q1   | 0.0838   |
# | loss_q2   | 0.0782   |
# | loss_q3   | 0.0831   |
# | mse       | 0.0814   |
# | mse_q0    | 0.0787   |
# | mse_q1    | 0.0838   |
# | mse_q2    | 0.0782   |
# | mse_q3    | 0.0831   |
# | nll       | 0.671    |
# | nll_q0    | 0.00104  |
# | nll_q1    | 0.0427   |
# | nll_q2    | 0.405    |
# | nll_q3    | 1.54     |
# | samples   | 6.72e+04 |
# | step      | 2.1e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0676   |
# | loss      | 0.0791   |
# | loss_q0   | 0.0773   |
# | loss_q1   | 0.0739   |
# | loss_q2   | 0.0824   |
# | loss_q3   | 0.0801   |
# | mse       | 0.0791   |
# | mse_q0    | 0.0773   |
# | mse_q1    | 0.0739   |
# | mse_q2    | 0.0824   |
# | mse_q3    | 0.0801   |
# | nll       | 0.723    |
# | nll_q0    | 0.00483  |
# | nll_q1    | 0.0147   |
# | nll_q2    | 0.386    |
# | nll_q3    | 1.5      |
# | samples   | 6.79e+04 |
# | step      | 2.12e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0653   |
# | loss      | 0.0768   |
# | loss_q0   | 0.074    |
# | loss_q1   | 0.0773   |
# | loss_q2   | 0.0827   |
# | loss_q3   | 0.0738   |
# | mse       | 0.0768   |
# | mse_q0    | 0.074    |
# | mse_q1    | 0.0773   |
# | mse_q2    | 0.0827   |
# | mse_q3    | 0.0738   |
# | nll       | 0.628    |
# | nll_q0    | 5.45e-08 |
# | nll_q1    | 0.0412   |
# | nll_q2    | 0.435    |
# | nll_q3    | 1.25     |
# | samples   | 6.85e+04 |
# | step      | 2.14e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.066    |
# | loss      | 0.078    |
# | loss_q0   | 0.0779   |
# | loss_q1   | 0.075    |
# | loss_q2   | 0.0748   |
# | loss_q3   | 0.0817   |
# | mse       | 0.078    |
# | mse_q0    | 0.0779   |
# | mse_q1    | 0.075    |
# | mse_q2    | 0.0748   |
# | mse_q3    | 0.0817   |
# | nll       | 0.645    |
# | nll_q0    | 9.6e-08  |
# | nll_q1    | 0.0247   |
# | nll_q2    | 0.297    |
# | nll_q3    | 1.43     |
# | samples   | 6.92e+04 |
# | step      | 2.16e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0631   |
# | loss      | 0.0752   |
# | loss_q0   | 0.0811   |
# | loss_q1   | 0.0714   |
# | loss_q2   | 0.0752   |
# | loss_q3   | 0.075    |
# | mse       | 0.0752   |
# | mse_q0    | 0.0811   |
# | mse_q1    | 0.0714   |
# | mse_q2    | 0.0752   |
# | mse_q3    | 0.075    |
# | nll       | 0.606    |
# | nll_q0    | 0.000273 |
# | nll_q1    | 0.0292   |
# | nll_q2    | 0.303    |
# | nll_q3    | 1.29     |
# | samples   | 6.98e+04 |
# | step      | 2.18e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0689   |
# | loss      | 0.0783   |
# | loss_q0   | 0.0755   |
# | loss_q1   | 0.0802   |
# | loss_q2   | 0.0737   |
# | loss_q3   | 0.0814   |
# | mse       | 0.0783   |
# | mse_q0    | 0.0755   |
# | mse_q1    | 0.0802   |
# | mse_q2    | 0.0737   |
# | mse_q3    | 0.0814   |
# | nll       | 0.688    |
# | nll_q0    | 0.00253  |
# | nll_q1    | 0.0388   |
# | nll_q2    | 0.296    |
# | nll_q3    | 1.54     |
# | samples   | 7.04e+04 |
# | step      | 2.2e+03  |
# ------------------------
# ------------------------
# | grad_norm | 0.0662   |
# | loss      | 0.0769   |
# | loss_q0   | 0.0781   |
# | loss_q1   | 0.0777   |
# | loss_q2   | 0.0725   |
# | loss_q3   | 0.0783   |
# | mse       | 0.0769   |
# | mse_q0    | 0.0781   |
# | mse_q1    | 0.0777   |
# | mse_q2    | 0.0725   |
# | mse_q3    | 0.0783   |
# | nll       | 0.67     |
# | nll_q0    | 0.0207   |
# | nll_q1    | 0.0297   |
# | nll_q2    | 0.315    |
# | nll_q3    | 1.4      |
# | samples   | 7.11e+04 |
# | step      | 2.22e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.0648   |
# | loss      | 0.0757   |
# | loss_q0   | 0.078    |
# | loss_q1   | 0.0704   |
# | loss_q2   | 0.0788   |
# | loss_q3   | 0.0756   |
# | mse       | 0.0757   |
# | mse_q0    | 0.078    |
# | mse_q1    | 0.0704   |
# | mse_q2    | 0.0788   |
# | mse_q3    | 0.0756   |
# | nll       | 0.641    |
# | nll_q0    | 6.66e-07 |
# | nll_q1    | 0.0242   |
# | nll_q2    | 0.36     |
# | nll_q3    | 1.34     |
# | samples   | 7.17e+04 |
# | step      | 2.24e+03 |
# ------------------------
# WARNING:torch.distributed.elastic.multiprocessing.api:Sending process 9360 closing signal SIGTERM
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/server/api.py", line 709, in run
#     result = self._invoke_run(role)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/server/api.py", line 850, in _invoke_run
#     time.sleep(monitor_interval)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py", line 62, in _terminate_process_handler
#     raise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
# torch.distributed.elastic.multiprocessing.api.SignalException: Process 9348 got signal: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/logging/__init__.py", line 1697, in isEnabledFor
#     return self._cache[level]
# KeyError: 30
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launch.py", line 195, in <module>
#     main()
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launch.py", line 191, in main
#     launch(args)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launch.py", line 176, in launch
#     run(args)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/run.py", line 753, in run
#     elastic_launch(
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launcher/api.py", line 132, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/launcher/api.py", line 237, in launch_agent
#     result = agent.run()
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/metrics/api.py", line 129, in wrapper
#     result = f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/agent/server/api.py", line 715, in run
#     log.warning(f"Received {e.sigval} death signal, shutting down workers")
#   File "/usr/lib/python3.9/logging/__init__.py", line 1457, in warning
#     if self.isEnabledFor(WARNING):
#   File "/usr/lib/python3.9/logging/__init__.py", line 1699, in isEnabledFor
#     _acquireLock()
#   File "/usr/lib/python3.9/logging/__init__.py", line 218, in _acquireLock
#     def _acquireLock():
#   File "/usr/local/lib/python3.9/dist-packages/torch/distributed/elastic/multiprocessing/api.py", line 62, in _terminate_process_handler
#     raise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
# torch.distributed.elastic.multiprocessing.api.SignalException: Process 9348 got signal: 2
# Traceback (most recent call last):
#   File "/content/drive/My Drive/code/DiffuSeq/train.py", line 120, in <module>
#     main()
#   File "/content/drive/My Drive/code/DiffuSeq/train.py", line 97, in main
#     TrainLoop(
#   File "/content/drive/My Drive/code/DiffuSeq/train_util.py", line 177, in run_loop
#     batch, cond = next(self.data)
#   File "/content/drive/My Drive/code/DiffuSeq/diffuseq/text_datasets.py", line 62, in infinite_loader
#     yield from data_loader
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 628, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 671, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 58, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 58, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/content/drive/My Drive/code/DiffuSeq/diffuseq/text_datasets.py", line 199, in __getitem__
#     out_kwargs['input_mask'] = np.array(self.text_datasets['train'][idx]['input_mask'])
#   File "/usr/local/lib/python3.9/dist-packages/datasets/arrow_dataset.py", line 2658, in __getitem__
#     return self._getitem(key)
#   File "/usr/local/lib/python3.9/dist-packages/datasets/arrow_dataset.py", line 2643, in _getitem
#     formatted_output = format_table(
#   File "/usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py", line 634, in format_table
#     return formatter(pa_table, query_type=query_type)
#   File "/usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py", line 406, in __call__
#     return self.format_row(pa_table)
#   File "/usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py", line 441, in format_row
#     row = self.python_arrow_extractor().extract_row(pa_table)
#   File "/usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py", line 144, in extract_row
#     return _unnest(pa_table.to_pydict())
# KeyboardInterrupt
# wandb: Waiting for W&B process to finish... (failed 255). Press Control-C to abort syncing.
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/wandb_manager.py", line 187, in _teardown
#     result = self._service.join()
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/service/service.py", line 216, in join
#     ret = self._internal_proc.wait()
#   File "/usr/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/usr/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/usr/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# wandb:
# wandb: Run history:
# wandb:    eval_loss █▂▁
# wandb: eval_loss_q0 █▁▁
# wandb: eval_loss_q1 █▁▁
# wandb: eval_loss_q2 █▁▁
# wandb: eval_loss_q3 █▂▁
# wandb:     eval_mse █▂▁
# wandb:  eval_mse_q0 █▁▁
# wandb:  eval_mse_q1 █▁▁
# wandb:  eval_mse_q2 █▁▁
# wandb:  eval_mse_q3 █▂▁
# wandb:     eval_nll █▂▁
# wandb:  eval_nll_q0 █▁▁
# wandb:  eval_nll_q1 █▁▁
# wandb:  eval_nll_q2 █▁▁
# wandb:  eval_nll_q3 █▃▁
# wandb:    grad_norm ██▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         loss █▅▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      loss_q0 █▅▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      loss_q1 █▅▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      loss_q2 █▅▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      loss_q3 █▅▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          mse █▅▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       mse_q0 █▅▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       mse_q1 █▅▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       mse_q2 █▅▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       mse_q3 █▅▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          nll ▆█▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       nll_q0 ▇█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       nll_q1 ▇█▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       nll_q2 ▆█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       nll_q3 ▆█▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      samples ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:         step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:
# wandb: Run summary:
# wandb:    eval_loss 0.07828
# wandb: eval_loss_q0 0.07383
# wandb: eval_loss_q1 0.06884
# wandb: eval_loss_q2 0.0846
# wandb: eval_loss_q3 0.08416
# wandb:     eval_mse 0.07828
# wandb:  eval_mse_q0 0.07383
# wandb:  eval_mse_q1 0.06884
# wandb:  eval_mse_q2 0.0846
# wandb:  eval_mse_q3 0.08416
# wandb:     eval_nll 0.63547
# wandb:  eval_nll_q0 0.0
# wandb:  eval_nll_q1 0.01209
# wandb:  eval_nll_q2 0.10942
# wandb:  eval_nll_q3 1.52405
# wandb:    grad_norm 0.06483
# wandb:         loss 0.07572
# wandb:      loss_q0 0.07799
# wandb:      loss_q1 0.07039
# wandb:      loss_q2 0.07878
# wandb:      loss_q3 0.0756
# wandb:          mse 0.07572
# wandb:       mse_q0 0.07799
# wandb:       mse_q1 0.07039
# wandb:       mse_q2 0.07878
# wandb:       mse_q3 0.0756
# wandb:          nll 0.6406
# wandb:       nll_q0 0.0
# wandb:       nll_q1 0.02423
# wandb:       nll_q2 0.35951
# wandb:       nll_q3 1.34149
# wandb:      samples 71712
# wandb:         step 2240
# wandb:
# wandb: 🚀 View run diffusion_models/diffuseq_gec_h128_lr0.0001_t1000_sqrt_lossaware_seed102_gec_err2corr120230327-06:17:25 at: https://wandb.ai/dl123/DiffuSeq/runs/j83mlvx6
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230327_061814-j83mlvx6/logs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7ebc53009287> in <module>
# ----> 1 get_ipython().system('cd "/content/drive/My Drive/code/DiffuSeq" &&  python -m torch.distributed.launch --nproc_per_node=1 --master_port=12233 --use_env scripts/run_train.py  --diff_steps 1000  --lr 0.0001  --learning_steps 20000  --save_interval 1000  --seed 102  --noise_schedule sqrt  --hidden_dim 128  --bsz 32  --dataset gec  --data_dir "datasets/GEC-9MB/err2corr"  --vocab bert  --seq_len 128  --schedule_sampler lossaware  --notes gec_err2corr1')
#       2
#       3 # --use_plm_init bert \
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      96       kwargs.update({'also_return_output': True})
#      97
# ---> 98     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      99
#     100     if pip_warn:
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     201       os.close(child_pty)
#     202
# --> 203       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     204   finally:
#     205     epoll.close()
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     231   while True:
#     232     try:
# --> 233       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     234       if result is not None:
#     235         return result
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     279   output_available = False
#     280
# --> 281   events = epoll.poll()
#     282   input_events = []
#     283   for _, event in events:
#
# KeyboardInterrupt:
